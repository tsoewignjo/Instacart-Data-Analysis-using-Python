# %% [markdown]
# ### Python Fundamentals for Data Analysts

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### Content

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
# Set path for environment
path = r'C:\Users\tsoew\OneDrive\Desktop\InstaCart Basket Analysis'

# %%
# Loading customers.csv
df_cust = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
sns.heatmap(df_cust.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.set_style('whitegrid')
sns.countplot(x='n_dependants', data=df_cust, palette='RdBu_r')
# Out:
# <Axes: xlabel='n_dependants', ylabel='count'>

# %%
sns.countplot(x='STATE', data=df_cust, palette='RdBu_r')
# Out:
# <Axes: xlabel='STATE', ylabel='count'>

# %%
sns.countplot(x='n_dependants',hue='Gender', data=df_cust, palette='RdBu_r')
# Out:
# <Axes: xlabel='n_dependants', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='n_dependants', data=df_cust, palette='RdBu_r')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='n_dependants', data=df_cust, palette='RdBu_r')

# %%
sns.distplot(df_cust['Age'].dropna(),kde=False,color='darkred',bins=30)
# Out:
# C:\Users\tsoew\AppData\Local\Temp\ipykernel_12868\1101442577.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_cust['Age'].dropna(),kde=False,color='darkred',bins=30)
# <Axes: xlabel='Age'>

# %%
sns.countplot(x='Gender',hue='fam_status', data=df_cust, palette='RdBu_r')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Loading products.csv
df_product = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_product.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Loading orders.csv minus eval_set column
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
df_order = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
df_order.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
sns.heatmap(df_order.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='order_dow', data=df_order, palette='RdBu_r')
# Out:
# <Axes: xlabel='order_dow', ylabel='count'>

# %%
sns.countplot(x='order_hour_of_day', data=df_order, palette='RdBu_r')
# Out:
# <Axes: xlabel='order_hour_of_day', ylabel='count'>

# %%
sns.countplot(x='days_since_prior_order', data=df_order, palette='RdBu_r')
# Out:
# <Axes: xlabel='days_since_prior_order', ylabel='count'>

# %%
sns.set_style('whitegrid')
# sns.countplot(x='Survived',hue='Sex',data=train,palette='RdBu_r')

# %% [markdown]
# # End
